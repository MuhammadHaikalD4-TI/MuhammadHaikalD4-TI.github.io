# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHaikalD4-TI/MuhammadHaikalD4-TI.github.io/blob/main/3A_20_Muhammad_Haikal_Buldan_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##***Langkah (Step) 1 :***

# %%
from google.colab import drive

# Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# code : 4/1AY0e-g7om9O27A085XMnRqPLlhB5ORmWiaorPLC8dOGI6P334mdlESUBUlE

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kucing.jpg')
plt.imshow(img)          #perhatikan hasilnya adalah citra dgn channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap= 'gray')

# %%
plt.imshow(img_gray, cmap= 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/kucing.tiff',img5)

#tampilkan plot dengan ukuran yang lebih besar
fig = plt.figure(figsize=(10,10))       #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(348,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 menunjukkan bahwa tiap titik dibuat 3 channel yang memiliki R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# #📃***Tugas***

# %%
# nomor 1
# Red-Green
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
# Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
# nomor 2
img_e = img[10:100,10:100]
plt.imshow(img_e)

# %%
# nomor 3
plt.imshow(img[5:30])

# %%
# nomor 4
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(100,100), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(200,100), pt2=(400,200), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(400,250), pt2=(300,300), color=(255,255,255),thickness=10)
cv.rectangle(img_ktk, pt1=(100,320), pt2=(160,260), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(620,190), pt2=(400,450), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %%
# nomor 5
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img_1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kucing.jpg')
plt.imshow(img_1)

# %%
img_rgb = cv.cvtColor(img_1,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(250,50),pt2=(500,300),color=(0,0,255),thickness=15)
plt.imshow(img_rgb)

# %%
cv.circle(img_rgb,center=(380,180),radius=80,color=(255,0,0),thickness=8)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(100,300),pt2=(10,350),color=(0,255,0),thickness=10)
plt.imshow(img_rgb)
